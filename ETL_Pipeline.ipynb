# %%
pip install spotipy
# Out:
# ...
#
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = "3421b9fcabf641a189550b046db5eee7", client_secret = "9f5d6af9543f4b92903b00a983a7efaf")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
#Authentication is verifying a user's account, while authorization is determining their access rights.
#Logging in with a password is authentication, while checking if the user can access a specific page is authorization.
#SpotifyClientCredentials is a method in the Spotify Web API for authenticating an application using client ID and client secret.(permission to extract data from spotify)
#Spotify is a function - it can be used for extracting the data from spotify by creating an object(used for authorization)

# %%
playlist_link = "https://open.spotify.com/playlist/6BTaAWwWNI5Nm49aUJkvOr"

# %%
#copied spotify url for top telugu most listened

# %%
playlistURI = playlist_link.split("/")[-1]

# %%
#6BTaAWwWNI5Nm49aUJkvOr is the playlist id - so extract using split function

# %%
#sp.playlist_tracks(playlistURI)

# %%
#playlist_tracks is a function to get data from the id(JSON Data)

# %%
data = sp.playlist_tracks(playlistURI)

# %%
#need to extract three different things - Albums, Artist, Songs

# %%
print(data)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/6BTaAWwWNI5Nm49aUJkvOr/tracks?offset=0&limit=100&additional_types=track', 'items': [{'added_at': '2021-12-29T16:26:56Z', 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/pnk53xjs234bqua1v5azk4l0y'}, 'href': 'https://api.spotify.com/v1/users/pnk53xjs234bqua1v5azk4l0y', 'id': 'pnk53xjs234bqua1v5azk4l0y', 'type': 'user', 'uri': 'spotify:user:pnk53xjs234bqua1v5azk4l0y'}, 'is_local': False, 'primary_color': None, 'track': {'preview_url': 'https://p.scdn.co/mp3-preview/08e9e850addd8b34f24fb6ad67d225d1aadb5737?cid=3421b9fcabf641a189550b046db5eee7', 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP
# ...

# %%
data['items'][0] #checking each album to easy understand and easy transformation
# Out:
# {'added_at': '2021-12-29T16:26:56Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/pnk53xjs234bqua1v5azk4l0y'},
#   'href': 'https://api.spotify.com/v1/users/pnk53xjs234bqua1v5azk4l0y',
#   'id': 'pnk53xjs234bqua1v5azk4l0y',
#   'type': 'user',
#   'uri': 'spotify:user:pnk53xjs234bqua1v5azk4l0y'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': 'https://p.scdn.co/mp3-preview/08e9e850addd8b34f24fb6ad67d225d1aadb5737?cid=3421b9fcabf641a189550b046db5eee7',
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
# ...

# %%
len(data['items']) #checking length of the api
# Out:
# 98

# %%
data['items'][0]['track'] #check track once what is there in the track details
# Out:
# {'preview_url': 'https://p.scdn.co/mp3-preview/08e9e850addd8b34f24fb6ad67d225d1aadb5737?cid=3421b9fcabf641a189550b046db5eee7',
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
# ...

# %%
data['items'][0]['track']['album']['name']   #first ablum name
# Out:
# 'Gang Leader (Original Motion Picture Soundtrack)'

# %%
data['items'][0]['track']['album']['external_urls']['spotify']  #first album song name
# Out:
# 'https://open.spotify.com/album/3JdE4IkqObXwTWzYKieCUv'

# %%
#every song has unique id - so extract id of first album id
data['items'][0]['track']['album']['id']
# Out:
# '3JdE4IkqObXwTWzYKieCUv'

# %%
data['items'][0]['track']['album']['release_date']  #first album release date
# Out:
# '2019-09-05'

# %%
data['items'][0]['track']['album']['total_tracks']  #first album total tracks
# Out:
# 4

# %%
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    print(album_id)
#check with any one column using print - all album id are printing
# Out:
# 3JdE4IkqObXwTWzYKieCUv
# 3PbLl0McqSI8V1cNHcc2DK
# 33bGNKG4SqamfmuenEbtcn
# 6edNaUK05Nxpxd4lWQ8Kt2
# 1LwCzBciwXJwMuZKQj0bf6
# 7EvKnbGkPEa6eNqUBpErN4
# 58NXiVpUmNSTBYYrPjuzqD
# 0OoEFhoQlSEubB7edcGCQ8
# 3XXCdggLOjADCViuXhn2XM
# 4Obc7YRza2GG7doBkJ5HrX
# 3BQo5xJMds0LOpSZqnsHpx
# 1fqfENcKu7uIBmYWMTTiNX
# 7zeJtHUSAZwlpXUijYJAsn
# 7zeJtHUSAZwlpXUijYJAsn
# 7euh83DiFlzDHsXEY28Cnt
# 5LDMi2W1Lu0HB4eXb2uHEa
# 55SWR8R1XvlvDMFaWZPWwK
# 2qPF34ldSTpFg8SEywoQ8E
# 4XYrygPHEzbjHZQVENBxk5
# 2qsU5yXnaBF5dyUQPTpZUm
# 3i0yyqAxnVUW0XWitqUiG8
# 6RsL60SSZTVwigjfyY8mD2
# 41uG5Q27NGJM3Uyb9FKZJI
# 5lmcmry7Mynwt2GSCJHQcV
# 39nh3qytgV0J3BPouBhak4
# 0Rl19vaibNaG5hAulfbqUO
# 6Tf5p3D2OTxd2zMdVIhyBU
# 5Xi56u0KdGlfJ3T6GEKQGn
# 3vHxGFNrNmkIwneqTFqnj1
# 16FbjE4zTKmqoa9DOt4lrs
# 6zZkpEfTu4MkMpN0roz884
# 2394D0vwxXW80JtLlYSuWj
# 6e7xxoyqjr3XRtl4N2BWJK
# 2q2iHTBhblTMdAuhgRsSVf
# 3ugmSyjGG6HJqZJPPiLftn
# 1iyTadvfpktJDCLF9GmHbL
# 0hEOFNB9mbDArzI1rQE2QE
# 3rpmVMH5kV6jYkzSmlpn5u
# 44odhvJguFB2Q8VoZupcFC
# 3i0yyqAxnVUW0XWitqUiG8
# ...

# %%
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    #we have to convert to dataframe - so first these data we are converting to dictionary then dictinoary to dataframe
    album_element = {'album_id':album_id, 'album_name':album_name, 'album_release_date': album_release_date, 'album_total_tracks': album_total_tracks, 'album_url':album_url}
    print(album_element)
# Out:
# {'album_id': '3JdE4IkqObXwTWzYKieCUv', 'album_name': 'Gang Leader (Original Motion Picture Soundtrack)', 'album_release_date': '2019-09-05', 'album_total_tracks': 4, 'album_url': 'https://open.spotify.com/album/3JdE4IkqObXwTWzYKieCUv'}
# {'album_id': '3PbLl0McqSI8V1cNHcc2DK', 'album_name': 'Emo Emo Emo Nannu Taake Haaye Premo', 'album_release_date': '2020-04-08', 'album_total_tracks': 1, 'album_url': 'https://open.spotify.com/album/3PbLl0McqSI8V1cNHcc2DK'}
# {'album_id': '33bGNKG4SqamfmuenEbtcn', 'album_name': 'Nuvve Nuvve (From "Red")', 'album_release_date': '2020-03-06', 'album_total_tracks': 1, 'album_url': 'https://open.spotify.com/album/33bGNKG4SqamfmuenEbtcn'}
# {'album_id': '6edNaUK05Nxpxd4lWQ8Kt2', 'album_name': 'Colour Photo', 'album_release_date': '2020-09-21', 'album_total_tracks': 1, 'album_url': 'https://open.spotify.com/album/6edNaUK05Nxpxd4lWQ8Kt2'}
# ...

# %%
#create list of dictinaries
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id, 'album_name':album_name, 'album_release_date': album_release_date, 'album_total_tracks': album_total_tracks, 'album_url':album_url}
    album_list.append(album_element)

# %%
album_list  #now it is very clean
# Out:
# [{'album_id': '3JdE4IkqObXwTWzYKieCUv',
#   'album_name': 'Gang Leader (Original Motion Picture Soundtrack)',
#   'album_release_date': '2019-09-05',
#   'album_total_tracks': 4,
#   'album_url': 'https://open.spotify.com/album/3JdE4IkqObXwTWzYKieCUv'},
#  {'album_id': '3PbLl0McqSI8V1cNHcc2DK',
#   'album_name': 'Emo Emo Emo Nannu Taake Haaye Premo',
#   'album_release_date': '2020-04-08',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/3PbLl0McqSI8V1cNHcc2DK'},
#  {'album_id': '33bGNKG4SqamfmuenEbtcn',
#   'album_name': 'Nuvve Nuvve (From "Red")',
#   'album_release_date': '2020-03-06',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/33bGNKG4SqamfmuenEbtcn'},
#  {'album_id': '6edNaUK05Nxpxd4lWQ8Kt2',
#   'album_name': 'Colour Photo',
#   'album_release_date': '2020-09-21',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/6edNaUK05Nxpxd4lWQ8Kt2'},
#  {'album_id': '1LwCzBciwXJwMuZKQj0bf6',
# ...

# %%
#now do it for artist
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'},
#   'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#   'id': '4zCH9qm4R2DADamUHMCa6O',
#   'name': 'Anirudh Ravichander',
#   'type': 'artist',
#   'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/29cBzYwqCZF4fjCisS8UvU'},
#   'href': 'https://api.spotify.com/v1/artists/29cBzYwqCZF4fjCisS8UvU',
#   'id': '29cBzYwqCZF4fjCisS8UvU',
#   'name': 'Inno Genga',
#   'type': 'artist',
#   'uri': 'spotify:artist:29cBzYwqCZF4fjCisS8UvU'}]

# %%
data['items'][0]['track']['artists']['id']  #artist id - throws errors - because it is in list of dictinories(2 dictionaries)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 data['items'][0]['track']['artists']['id']
#
# TypeError: list indices must be integers or slices, not str

# %%
data['items'][0]['track']['artists'][0]['id'] #first artist id - it is in dictionary(because one album has multiple artists)
# Out:
# '4zCH9qm4R2DADamUHMCa6O'

# %%
data['items'][0]['track']['artists'][0]['name'] #first artist name
# Out:
# 'Anirudh Ravichander'

# %%
data['items'][0]['track']['artists'][0]['type'] #first artist type
# Out:
# 'artist'

# %%
data['items'][0]['track']['artists'][0]['external_urls']['spotify'] #first artisturl
# Out:
# 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'

# %%
data['items'][0]['track']['artists'][1]['id'] #second artist id
# Out:
# '29cBzYwqCZF4fjCisS8UvU'

# %%
data['items'][0]['track']['artists'][1]['name'] #second artist name
# Out:
# 'Inno Genga'

# %%
data['items'][0]['track']['artists'][1]['type'] #second artist type
# Out:
# 'artist'

# %%
data['items'][0]['track']['artists'][1]['external_urls']['spotify'] #second artist url
# Out:
# 'https://open.spotify.com/artist/29cBzYwqCZF4fjCisS8UvU'

# %%
for row in data['items']:
    for key,value in row.items():
        if key == 'track':
            print(key,value)
            
#please google it for more info - took each item from data['items'] and check it in key,value pair(because i have list of 
#dictinoaries. in that dictionaries i have to check tracks so i used if condition to check key and print the tracks.)
# Out:
# track {'preview_url': 'https://p.scdn.co/mp3-preview/08e9e850addd8b34f24fb6ad67d225d1aadb5737?cid=3421b9fcabf641a189550b046db5eee7', 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC
# ...

# %%
for row in data['items']:
    for key,value in row.items():
        if key == 'track':
            for artist in value['artists']:
                print(artist)
#to get the all artist data(in each album we have multiple artists)
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'}, 'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O', 'id': '4zCH9qm4R2DADamUHMCa6O', 'name': 'Anirudh Ravichander', 'type': 'artist', 'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/29cBzYwqCZF4fjCisS8UvU'}, 'href': 'https://api.spotify.com/v1/artists/29cBzYwqCZF4fjCisS8UvU', 'id': '29cBzYwqCZF4fjCisS8UvU', 'name': 'Inno Genga', 'type': 'artist', 'uri': 'spotify:artist:29cBzYwqCZF4fjCisS8UvU'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/2W19xkR3LeyE7zvES5ULvb'}, 'href': 'https://api.spotify.com/v1/artists/2W19xkR3LeyE7zvES5ULvb', 'id': '2W19xkR3LeyE7zvES5ULvb', 'name': 'Pravin Lakkaraju', 'type': 'artist', 'uri': 'spotify:artist:2W19xkR3LeyE7zvES5ULvb'}
# ...

# %%
for row in data['items']:
    for key,value in row.items():
        if key == 'track':
            for artist in value['artists']: #i have used for here - because i have list of artists
                artist_id = artist['id']
                print(artist_id)
#check all artist are printing
# Out:
# 4zCH9qm4R2DADamUHMCa6O
# 29cBzYwqCZF4fjCisS8UvU
# 2W19xkR3LeyE7zvES5ULvb
# 4svvMm4TQnkphZJfhLCzzv
# 6LWyVEIBnx7MoRBhQxu9om
# 6LWyVEIBnx7MoRBhQxu9om
# 4tejKImNVmDcORNBuZ1l14
# 7qjJw7ZM2ekDSahLXPjIlN
# 4xlqU0G9EloUPHL1qlmWY6
# 6LWyVEIBnx7MoRBhQxu9om
# 0WiZi3Q419nMpAQEqfBCbk
# 4IKVDbCSBTxBeAsMKjAuTs
# 6KjiNHnbm1CNrIN0z7wJtO
# 2ae6PxICSOZHvjqiCcgon8
# 2JEjaa7hWhE1BbL3OcoeFR
# 1mYsTxnqsietFxj1OgoGbG
# 2ae6PxICSOZHvjqiCcgon8
# 1H2WiaO7p3zNNmjoBznv70
# 6qJdT7Ol8lHV3I2ONq9hBi
# 2ae6PxICSOZHvjqiCcgon8
# 0mV4UQ0gHg59AAUtg968pX
# 5OTt6O4Q22YsqZDaWV6FqC
# 0mV4UQ0gHg59AAUtg968pX
# 4chi55fx5usXwPsJq1g2a3
# 7HCfn98lJJNkmv6Gn0F2Fc
# 5GnnSrwNCGyfAU4zuIytiS
# 1QvyquqkuuwUzdszyoKIy4
# 3RSD5gKYj6AflNrO9GGGyO
# 1L458p6NDHNm1CEgCVKLwW
# 2ae6PxICSOZHvjqiCcgon8
# 2IUtwMti1OiT3lkW6RubgH
# 1QvyquqkuuwUzdszyoKIy4
# 26FsIvdczntiZCsifDzKOK
# 5ugSzRux2CJD4YuXJNcxad
# 0aUQnP4HhUQXcurZl9GJIA
# 09Swfzp0iwV8Yxe1Ngzf6v
# 2OrTfOi3k8VMFLuvC527bB
# 1plObTufEAfeL1hk8Qz24v
# 7zFBW2JxM4bgTTKxCRcS8Q
# 4zCH9qm4R2DADamUHMCa6O
# ...

# %%
artist_list = []
for row in data['items']:
    for key,value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_id = artist['id']
                artist_name = artist['name']
                artist_type = artist['type']
                artist_url = artist['external_urls']['spotify']
                artist_element = {'artist_id': artist_id, 'artist_name': artist_name, 'artist_type': artist_type,
                                 'artist_url': artist_url}
                artist_list.append(artist_element)
                
#Converting to dictionaries and store it in list of dictionaries

# %%
artist_list
# Out:
# [{'artist_id': '4zCH9qm4R2DADamUHMCa6O',
#   'artist_name': 'Anirudh Ravichander',
#   'artist_type': 'artist',
#   'artist_url': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'},
#  {'artist_id': '29cBzYwqCZF4fjCisS8UvU',
#   'artist_name': 'Inno Genga',
#   'artist_type': 'artist',
#   'artist_url': 'https://open.spotify.com/artist/29cBzYwqCZF4fjCisS8UvU'},
#  {'artist_id': '2W19xkR3LeyE7zvES5ULvb',
#   'artist_name': 'Pravin Lakkaraju',
#   'artist_type': 'artist',
#   'artist_url': 'https://open.spotify.com/artist/2W19xkR3LeyE7zvES5ULvb'},
#  {'artist_id': '4svvMm4TQnkphZJfhLCzzv',
#   'artist_name': 'Ramya Behara',
#   'artist_type': 'artist',
#   'artist_url': 'https://open.spotify.com/artist/4svvMm4TQnkphZJfhLCzzv'},
#  {'artist_id': '6LWyVEIBnx7MoRBhQxu9om',
#   'artist_name': 'Anurag Kulkarni',
#   'artist_type': 'artist',
#   'artist_url': 'https://open.spotify.com/artist/6LWyVEIBnx7MoRBhQxu9om'},
#  {'artist_id': '6LWyVEIBnx7MoRBhQxu9om',
# ...

# %%
#now do it for songs
data['items'][0]['track']['name']  #extracting song name
# Out:
# 'Hoyna Hoyna'

# %%
data['items'][0]['track']['id'] #extracting song id
# Out:
# '7mNQwVYgoB3mtjkjCKsbXM'

# %%
data['items'][0]['track']['popularity'] #extracting song popularity
# Out:
# 58

# %%
data['items'][0]['track']['duration_ms'] #song duration
# Out:
# 271937

# %%
data['items'][0]['track']['external_urls']['spotify'] #song url
# Out:
# 'https://open.spotify.com/track/7mNQwVYgoB3mtjkjCKsbXM'

# %%
data['items'][0]['track']['album']['id'] #album id of the song
# Out:
# '3JdE4IkqObXwTWzYKieCUv'

# %%
data['items'][0]['track']['album']['name']  #album name of the song
# Out:
# 'Gang Leader (Original Motion Picture Soundtrack)'

# %%
data['items'][0]['track']['artists'][0]['id']  #artist id of the song(multiple artist will be there in each song)
# Out:
# '4zCH9qm4R2DADamUHMCa6O'

# %%
data['items'][0]['track']['artists'][0]['name']
# Out:
# 'Anirudh Ravichander'

# %%
data['items'][0]['track']['artists'][1]['id']
# Out:
# '29cBzYwqCZF4fjCisS8UvU'

# %%
data['items'][0]['track']['artists'][1]['name']
# Out:
# 'Inno Genga'

# %%
song_list = []
for row in data['items']:
    song_name = row['track']['name']
    print(song_name) #check once, it is getting or not
# Out:
# Hoyna Hoyna
# Emo Emo Emo Nannu Taake Haaye Premo
# Nuvve Nuvve (From "Red")
# Arere Aakasham - Telugu
# Manasa Manasa - Telugu
# Sirivennela
# Padi Padi Leche (From "Padi Padi Leche Manasu")
# Na Cheli Rojave (From "Roja")
# Prema Prema
# Jabilli Kosam-Male
# Sasivadane
# O Cheliya
# Challa Gaali Thakuthunna
# Idhera
# O Cheli Thaara
# Oh Velluvai - From "Sreekaram"
# Swathilo Muthyamantha (From "Bangaru Bullodu")
# Ay Pilla - Telugu
# Pillaa Raa (Unplugged) - From "RX 100"
# Ningi Chutte - Telugu
# I Wanna Fly
# Baitikochi Chuste
# Inka Koncham Saeppu
# Kathakaadhey
# Kannayya - Father's Love
# Prema Ishq Kaadhal
# So So Ga
# Ninnu Kori Tittle Song
# Kallumoosi
# Puttene Prema
# Kanapadava Male
# Apudo Ipudo
# Vagalaadi
# Neelambari
# Excuse Me Rakshasi - From "Ninu Veedani Needanu Nene"
# Srivalli (From "Pushpa - The Rise")(Telugu)
# Amigo
# Endhuko Emo
# Mate Rani
# Ela Ela
# Parugu Parugu
# Kallolam
# Cheppave Balamani
# Naalo Chilipi Kala (Theme Song)
# ...

# %%
song_list = []
for row in data['items']:
    song_name = row['track']['name']
    song_id = row['track']['id']
    song_popularity = row['track']['popularity']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    album_id = row['track']['album']['id']
    artist_id = row['track']['artists'][0]['id'] #taking only one artist
    artist_name = row['track']['artists'][0]['name']
    song_elements = {'song_name': song_name, 'song_id': song_id, 'song_popularity': song_popularity, 'song_duration':song_duration,
                    'song_url':song_url, 'album_id':album_id, 'artist_id': artist_id, 'artist_name': artist_name}
    song_list.append(song_elements)

# %%
song_list
# Out:
# [{'song_name': 'Hoyna Hoyna',
#   'song_id': '7mNQwVYgoB3mtjkjCKsbXM',
#   'song_popularity': 58,
#   'song_duration': 271937,
#   'song_url': 'https://open.spotify.com/track/7mNQwVYgoB3mtjkjCKsbXM',
#   'album_id': '3JdE4IkqObXwTWzYKieCUv',
#   'artist_id': '4zCH9qm4R2DADamUHMCa6O',
#   'artist_name': 'Anirudh Ravichander'},
#  {'song_name': 'Emo Emo Emo Nannu Taake Haaye Premo',
#   'song_id': '5GkNYFFmyDe0Y8zJYDEf71',
#   'song_popularity': 27,
#   'song_duration': 243000,
#   'song_url': 'https://open.spotify.com/track/5GkNYFFmyDe0Y8zJYDEf71',
#   'album_id': '3PbLl0McqSI8V1cNHcc2DK',
#   'artist_id': '2W19xkR3LeyE7zvES5ULvb',
#   'artist_name': 'Pravin Lakkaraju'},
#  {'song_name': 'Nuvve Nuvve (From "Red")',
#   'song_id': '7Ft65MCYElRCDo7jOekQFs',
#   'song_popularity': 0,
#   'song_duration': 253277,
#   'song_url': 'https://open.spotify.com/track/7Ft65MCYElRCDo7jOekQFs',
#   'album_id': '33bGNKG4SqamfmuenEbtcn',
#   'artist_id': '4svvMm4TQnkphZJfhLCzzv',
# ...

# %%
#now have to convert entire into proper dataframe using pandas
import pandas as pd

# %%
#check in google how dictinoary can be converted to pandas before - you will get some idea
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df
# Out:
#                   album_id                                        album_name  \
# 0   3JdE4IkqObXwTWzYKieCUv  Gang Leader (Original Motion Picture Soundtrack)
# 1   3PbLl0McqSI8V1cNHcc2DK               Emo Emo Emo Nannu Taake Haaye Premo
# 2   33bGNKG4SqamfmuenEbtcn                          Nuvve Nuvve (From "Red")
# 3   6edNaUK05Nxpxd4lWQ8Kt2                                      Colour Photo
# 4   1LwCzBciwXJwMuZKQj0bf6                            Most Eligible Bachelor
# ..                     ...                                               ...
# 93  7k4EcT3DDGPd2j73OgB6lR                                          Top Gear
# 94  40SOtgPjx3Ic3fI6wig7Qs                                          Lollipop
# 95  0o1VVpUsIYjBU0lur8D11O                                            Alluri
# 96  0zRFnm1hqjtY0c7ozMK2Lh                                Adipurush (TELUGU)
# 97  7h1jWklU81GDvg0N02TiH7                                           Varsham
#
#    album_release_date  album_total_tracks  \
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            98 non-null     object
#  1   album_name          98 non-null     object
#  2   album_release_date  98 non-null     object
#  3   album_total_tracks  98 non-null     int64
#  4   album_url           98 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
#drop duplicates
album_df = album_df.drop_duplicates(subset = ['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset = ['artist_id'])

# %%
artist_df
# Out:
#                   artist_id          artist_name artist_type  \
# 0    4zCH9qm4R2DADamUHMCa6O  Anirudh Ravichander      artist
# 1    29cBzYwqCZF4fjCisS8UvU           Inno Genga      artist
# 2    2W19xkR3LeyE7zvES5ULvb     Pravin Lakkaraju      artist
# 3    4svvMm4TQnkphZJfhLCzzv         Ramya Behara      artist
# 4    6LWyVEIBnx7MoRBhQxu9om      Anurag Kulkarni      artist
# ..                      ...                  ...         ...
# 178  34uPPT8En9O7fAEPO8S3Fp         Abhijith Rao      artist
# 179  1C3jeSsmZvfTHvoNlLuchi       Gayathry Rajiv      artist
# 180  5fvTHKKzW44A9867nPDocM            Ajay-Atul      artist
# 183  6CWBs7ul78QwnBrcOCwhf5                Sagar      artist
# 184  0WpkyIAATl5W540KCSEUwX            Sumangaly      artist
#
#                                             artist_url
# 0    https://open.spotify.com/artist/4zCH9qm4R2DADa...
# 1    https://open.spotify.com/artist/29cBzYwqCZF4fj...
# 2    https://open.spotify.com/artist/2W19xkR3LeyE7z...
# ...

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df = song_df.drop_duplicates(subset = ['song_id'])

# %%
song_df
# Out:
#                               song_name                 song_id  \
# 0                           Hoyna Hoyna  7mNQwVYgoB3mtjkjCKsbXM
# 1   Emo Emo Emo Nannu Taake Haaye Premo  5GkNYFFmyDe0Y8zJYDEf71
# 2              Nuvve Nuvve (From "Red")  7Ft65MCYElRCDo7jOekQFs
# 3               Arere Aakasham - Telugu  6w0C4Zk1SqRsZR3kCOiduW
# 4                Manasa Manasa - Telugu  4kEd65XC9mEFTiscE6f6N9
# ..                                  ...                     ...
# 93                      Vennela Vennela  2pZPSfj0EPZVHVlf42NTVB
# 94                             Lollipop  5ZtrYdXOsYCRLXuGKR7nt6
# 95                       Nee Choopulaku  0Yqtyfn1DRr5OdkxDGUPL5
# 96              Priya Mithunam (Telugu)  4wFU6Q4vInTg2HQ2mkko8x
# 97                   Neeti Mullai (Bit)  29ffQxBUZLJdN3kiPndB9n
#
#     song_popularity  song_duration  \
# 0                58         271937
# 1                27         243000
# 2                 0         253277
# 3                47         206250
# ...

# %%
album_df.to_csv('album.csv', index=False) #it will automatically download to the path which you are running jupyter

# %%
artist_df.to_csv('artist.csv', index=False)

# %%
song_df.to_csv('song.csv', index=False)

# %%
import os
folder_path = r'D:\azure\Github\ETL_USING_PYTHON\ouput_CSV'
os.makedirs(folder_path, exist_ok=True)
album_df.to_csv(os.path.join(folder_path, 'album.csv'), index=False)
artist_df.to_csv(os.path.join(folder_path, 'artist.csv'), index=False)
song_df.to_csv(os.path.join(folder_path, 'song.csv'), index=False)
#if you want to store files in seperate folder then you can use chatgpt for code.

# %%
#now load it into cloud(AWS,AZURE)

# %%
import boto3
from io import StringIO

# %%
pip install boto3  #boto3 is the package for uploading your DataFrame to AWS S3(boto3 library, which is the AWS SDK(Software Development Kit) for Python. It allows you to interact with various AWS services, including S3, EC2, Lambda, etc.)
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '#boto3': Expected package name at the start of dependency specifier
#     #boto3
#     ^

# %%
import boto3
from io import StringIO #StringIO is used to handle in-memory string data as if it were a file. This is useful when you want to create file-like objects without actually writing to disk.

# %%
aws_access_key_id = 'AKIA3FLD6LE5H7F6UGEO'
aws_secret_access_key = '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'
bucket_name = 'etlusingpythondataframesloads3'
file_name = 'album.csv'  # Name of the file in S3

# %%
csv_buffer = StringIO() #This creates an in-memory text stream using the StringIO class from the io module. This stream acts like a file object, but it exists in memory rather than being a physical file on the disk.
album_df.to_csv(csv_buffer, index=False) #This converts the DataFrame album_df into CSV format and writes the data into the csv_buffer in-memory stream. The index=False argument ensures that the DataFrame index is not written to the CSV.

# %%
s3_client = boto3.client('s3', 
                         aws_access_key_id=aws_access_key_id,
                         aws_secret_access_key=aws_secret_access_key) 
#The s3_client object can then be used to perform operations like uploading files, listing buckets, and managing objects in Amazon S3.
#s3_client = boto3.client('s3'): This creates a low-level S3 client using the AWS SDK for Python (boto3). The client method is used to interact with specific AWS services—in this case, Amazon S3.
#AWS credentials (Access Key ID and Secret Access Key) to authenticate the S3 client.

# %%
s3_client.put_object(Bucket='etlusingpythondataframesloads3', 
                     Body=csv_buffer.getvalue(), 
                     Key=file_name)
print(f'File {file_name} uploaded to bucket {bucket_name}')
#s3_client.put_object method in the boto3 library is used to upload (or "put") an object (file) into an Amazon S3 bucket.
#s3_client: This is an instance of the boto3.client('s3'), which you use to interact with the Amazon S3 service.
#put_object(): This method is used to upload or store data in an S3 bucket
#Bucket - Name of the bucket which you create in s3 to store
#Body: The actual data you want to upload. This can be a file, a string, or a byte stream. In your example, csv_buffer.getvalue() represents the CSV content stored in memory.
#Key: The name of the object (file) you want to create in the S3 bucket. This defines how the file will be named in the bucket. For instance, file_name is the file's name in S3
# Out:
# File album.csv uploaded to bucket etlusingpythondataframesloads3

# %%
file_name =  'artist.csv'
csv_buffer = StringIO()
artist_df.to_csv(csv_buffer, index=False)
s3_client.put_object(Bucket='etlusingpythondataframesloads3', 
                     Body=csv_buffer.getvalue(), 
                     Key=file_name)
print(f'File {file_name} uploaded to bucket {bucket_name}')
# Out:
# File artist.csv uploaded to bucket etlusingpythondataframesloads3

# %%
file_name =  'song.csv'
csv_buffer = StringIO()
song_df.to_csv(csv_buffer, index=False)
s3_client.put_object(Bucket='etlusingpythondataframesloads3', 
                     Body=csv_buffer.getvalue(), 
                     Key=file_name)
print(f'File {file_name} uploaded to bucket {bucket_name}')
# Out:
# File song.csv uploaded to bucket etlusingpythondataframesloads3

# %%
#note: Putobject security level permission errors will come - Use IAM(PutObject action in S3)
#IAM - IAM stands for Identity and Access Management. It is a service provided by AWS (Amazon Web Services) that helps you manage access to AWS resources securely. IAM allows you to control who can access your AWS resources and what actions they can perform.
#IAM - create policy - Give IAM name, Actions - PutObject(write), policy_name save.(then we have authorised the permission to wrtie the data in the S3)

# %%
pip install azure-storage-blob #The azure-storage-blob package allows Python applications to easily interact with Azure Blob Storage for uploading, downloading, and managing files in the cloud.
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '#The': Expected package name at the start of dependency specifier
#     #The
#     ^

# %%
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
from io import StringIO #StringIO is used to create an in-memory file-like object that stores strings, which can be useful for handling CSV data before uploading to cloud storage.

# %%
account_name = 'etlusingpython'
account_key = '2GaYGUTpWTHu/VLHy0K6U8mSvfGmXeDMq5BtzHA5GY3a8O5iKuG2Zqi5TOWsUrlfJNDJvLBPC1w3+AStX+Qaqw=='
container_name = 'etlloaddata'
#account_name - storageaccountname
#account_key - The account_key is a secure key used to authenticate and access your Azure Storage account.
#account key - storage account -> security + networking -> Access keys(you can use one key)
#container_name - name of the container where our files resides to store

# %%
blob_service_client = BlobServiceClient(
    account_url=f'https://{account_name}.blob.core.windows.net',
    credential=account_key
)
#BlobServiceClient is used to interact with Azure Blob Storage, allowing you to manage containers and blobs within your storage account.
#account_url: This is the URL of your Azure Storage account, constructed using the account_name.
#credential: This is where you provide the account_key to authenticate your access.
#these steps allows you to interact with the Azure Blob Storage account for tasks like uploading or downloading files.

# %%
container_client = blob_service_client.get_container_client(container_name)
#creates a client to interact with a specific container in Azure Blob Storage, allowing you to perform operations like uploading, downloading, and listing blobs within that container.
#get_container_client(container_name) is a method from the BlobServiceClient class in the Azure SDK. It returns a ContainerClient instance, which allows you to perform operations on the specified container, such as uploading and downloading blobs, listing the blobs in the container, and managing container-level properties.

# %%
csv_buffer = StringIO()
album_df.to_csv(csv_buffer, index=False)

# %%
blob_name = 'album.csv'

# %%
blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
#The get_blob_client(container=container_name, blob=blob_name) method of the BlobServiceClient class creates a BlobClient instance for the specified blob within the given container. 
#This BlobClient allows you to perform operations on that specific blob, such as uploading, downloading, or deleting the blob.

# %%
blob_client.upload_blob(csv_buffer.getvalue(), overwrite=True)
#upload_blob method uploads the content from csv_buffer to the specified blob in Azure Blob Storage. 
#The overwrite=True argument ensures that if a blob with the same name already exists, it will be replaced with the new data.
# Out:
# {'etag': '"0x8DCD16B8D60419C"',
#  'last_modified': datetime.datetime(2024, 9, 10, 7, 38, 24, tzinfo=datetime.timezone.utc),
#  'content_md5': bytearray(b'\x89\x91N\x19B\x07\xdc\xa6g\xd3\x18?\xf7\xfe\xad\x9b'),
#  'client_request_id': 'a83821b3-6f47-11ef-a5dd-c03eba28e78e',
#  'request_id': '26cafaf9-301e-0044-3154-03755e000000',
#  'version': '2024-08-04',
#  'version_id': None,
#  'date': datetime.datetime(2024, 9, 10, 7, 38, 23, tzinfo=datetime.timezone.utc),
#  'request_server_encrypted': True,
#  'encryption_key_sha256': None,
#  'encryption_scope': None}

# %%
print(f'File {blob_name} uploaded to container {container_name}')
# Out:
# File album.csv uploaded to container etlloaddata

# %%
csv_buffer = StringIO()
artist_df.to_csv(csv_buffer, index=False)
blob_name = 'artist.csv'
blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
blob_client.upload_blob(csv_buffer.getvalue(), overwrite=True)
print(f'File {blob_name} uploaded to container {container_name}')
# Out:
# File artist.csv uploaded to container etlloaddata

# %%
csv_buffer = StringIO()
song_df.to_csv(csv_buffer, index=False)
blob_name = 'song.csv'
blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
blob_client.upload_blob(csv_buffer.getvalue(), overwrite=True)
print(f'File {blob_name} uploaded to container {container_name}')
# Out:
# File song.csv uploaded to container etlloaddata

# %%
pip install pyodbc sqlalchemy pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
album_df
# Out:
#                   album_id                                        album_name  \
# 0   3JdE4IkqObXwTWzYKieCUv  Gang Leader (Original Motion Picture Soundtrack)
# 1   3PbLl0McqSI8V1cNHcc2DK               Emo Emo Emo Nannu Taake Haaye Premo
# 2   33bGNKG4SqamfmuenEbtcn                          Nuvve Nuvve (From "Red")
# 3   6edNaUK05Nxpxd4lWQ8Kt2                                      Colour Photo
# 4   1LwCzBciwXJwMuZKQj0bf6                            Most Eligible Bachelor
# ..                     ...                                               ...
# 93  7k4EcT3DDGPd2j73OgB6lR                                          Top Gear
# 94  40SOtgPjx3Ic3fI6wig7Qs                                          Lollipop
# 95  0o1VVpUsIYjBU0lur8D11O                                            Alluri
# 96  0zRFnm1hqjtY0c7ozMK2Lh                                Adipurush (TELUGU)
# 97  7h1jWklU81GDvg0N02TiH7                                           Varsham
#
#    album_release_date  album_total_tracks  \
# ...

# %%
artist_df
# Out:
#                   artist_id          artist_name artist_type  \
# 0    4zCH9qm4R2DADamUHMCa6O  Anirudh Ravichander      artist
# 1    29cBzYwqCZF4fjCisS8UvU           Inno Genga      artist
# 2    2W19xkR3LeyE7zvES5ULvb     Pravin Lakkaraju      artist
# 3    4svvMm4TQnkphZJfhLCzzv         Ramya Behara      artist
# 4    6LWyVEIBnx7MoRBhQxu9om      Anurag Kulkarni      artist
# ..                      ...                  ...         ...
# 178  34uPPT8En9O7fAEPO8S3Fp         Abhijith Rao      artist
# 179  1C3jeSsmZvfTHvoNlLuchi       Gayathry Rajiv      artist
# 180  5fvTHKKzW44A9867nPDocM            Ajay-Atul      artist
# 183  6CWBs7ul78QwnBrcOCwhf5                Sagar      artist
# 184  0WpkyIAATl5W540KCSEUwX            Sumangaly      artist
#
#                                             artist_url
# 0    https://open.spotify.com/artist/4zCH9qm4R2DADa...
# 1    https://open.spotify.com/artist/29cBzYwqCZF4fj...
# 2    https://open.spotify.com/artist/2W19xkR3LeyE7z...
# ...

# %%
song_df
# Out:
#                               song_name                 song_id  \
# 0                           Hoyna Hoyna  7mNQwVYgoB3mtjkjCKsbXM
# 1   Emo Emo Emo Nannu Taake Haaye Premo  5GkNYFFmyDe0Y8zJYDEf71
# 2              Nuvve Nuvve (From "Red")  7Ft65MCYElRCDo7jOekQFs
# 3               Arere Aakasham - Telugu  6w0C4Zk1SqRsZR3kCOiduW
# 4                Manasa Manasa - Telugu  4kEd65XC9mEFTiscE6f6N9
# ..                                  ...                     ...
# 93                      Vennela Vennela  2pZPSfj0EPZVHVlf42NTVB
# 94                             Lollipop  5ZtrYdXOsYCRLXuGKR7nt6
# 95                       Nee Choopulaku  0Yqtyfn1DRr5OdkxDGUPL5
# 96              Priya Mithunam (Telugu)  4wFU6Q4vInTg2HQ2mkko8x
# 97                   Neeti Mullai (Bit)  29ffQxBUZLJdN3kiPndB9n
#
#     song_popularity  song_duration  \
# 0                58         271937
# 1                27         243000
# 2                 0         253277
# 3                47         206250
# ...
